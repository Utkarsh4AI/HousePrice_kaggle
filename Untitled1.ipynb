# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
test_df =  pd.read_csv('test.csv')
test_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
null_test = test_df.isnull().sum().sort_values()
null_df = df.isnull().sum().sort_values()
null_test[null_test>0],null_df[null_df>0]
# Out:
# (GarageCars         1
#  GarageArea         1
#  KitchenQual        1
#  Exterior1st        1
#  SaleType           1
#  TotalBsmtSF        1
#  BsmtUnfSF          1
#  Exterior2nd        1
#  BsmtFinSF1         1
#  BsmtFinSF2         1
#  BsmtFullBath       2
#  Functional         2
#  Utilities          2
#  BsmtHalfBath       2
#  MSZoning           4
#  MasVnrArea        15
#  MasVnrType        16
#  BsmtFinType2      42
#  BsmtFinType1      42
#  BsmtExposure      44
#  BsmtQual          44
#  BsmtCond          45
#  GarageType        76
#  GarageFinish      78
#  GarageYrBlt       78
#  GarageQual        78
#  GarageCond        78
#  LotFrontage      227
#  FireplaceQu      730
#  Fence           1169
#  Alley           1352
#  MiscFeature     1408
#  PoolQC          1456
#  dtype: int64,
#  Electrical         1
#  MasVnrType         8
#  MasVnrArea         8
#  BsmtQual          37
#  BsmtCond          37
#  BsmtFinType1      37
#  BsmtFinType2      38
# ...

# %%
cat_col = df.select_dtypes(include='object').columns
cat_col
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
num_col = df.select_dtypes(include=['float64','int64']).columns
num_col
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
null_col = pd.DataFrame(null_df[null_df>0]).index
null_col
# Out:
# Index(['Electrical', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond',
#        'BsmtFinType1', 'BsmtFinType2', 'BsmtExposure', 'GarageQual',
#        'GarageFinish', 'GarageYrBlt', 'GarageType', 'GarageCond',
#        'LotFrontage', 'FireplaceQu', 'Fence', 'Alley', 'MiscFeature',
#        'PoolQC'],
#       dtype='object')

# %%
len(null_col)
# Out:
# 19

# %%
null_num = []
for i in num_col:
    if i in null_col:
        null_num.append(i)

# %%
null_num
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
null_cat = []
for i in cat_col:
    if i in null_col:
        null_cat.append(i)

# %%
null_cat
# Out:
# ['Alley',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
len(null_cat),len(null_num)
# Out:
# (16, 3)

# %%
null_df = df.isnull().sum().sort_values()
null_df[null_df>0]
# Out:
# Electrical         1
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# BsmtFinType2      38
# BsmtExposure      38
# GarageQual        81
# GarageFinish      81
# GarageYrBlt       81
# GarageType        81
# GarageCond        81
# LotFrontage      259
# FireplaceQu      690
# Fence           1179
# Alley           1369
# MiscFeature     1406
# PoolQC          1453
# dtype: int64

# %%
len(null_df[null_df>0])
# Out:
# 19

# %%
df.drop('PoolQC',axis=1,inplace=True)
df.drop(['MiscFeature','Alley'],axis=1,inplace=True)
df.drop('Fence',axis=1,inplace=True)

# %%
df.drop('Fence',axis=1,inplace=True)

# %%
null_df = df.isnull().sum().sort_values()
null_df[null_df>0],len(null_df[null_df>0])
# Out:
# (Electrical        1
#  MasVnrArea        8
#  MasVnrType        8
#  BsmtQual         37
#  BsmtCond         37
#  BsmtFinType1     37
#  BsmtFinType2     38
#  BsmtExposure     38
#  GarageCond       81
#  GarageQual       81
#  GarageFinish     81
#  GarageType       81
#  GarageYrBlt      81
#  LotFrontage     259
#  FireplaceQu     690
#  dtype: int64,
#  15)

# %%
null_col = pd.DataFrame(null_df[null_df>0]).index
null_col
# Out:
# Index(['Electrical', 'MasVnrArea', 'MasVnrType', 'BsmtQual', 'BsmtCond',
#        'BsmtFinType1', 'BsmtFinType2', 'BsmtExposure', 'GarageCond',
#        'GarageQual', 'GarageFinish', 'GarageType', 'GarageYrBlt',
#        'LotFrontage', 'FireplaceQu'],
#       dtype='object')

# %%
null_num = []
for i in num_col:
    if i in null_col:
        null_num.append(i)

# %%
null_cat = []
for i in cat_col:
    if i in null_col:
        null_cat.append(i)

# %%
null_num
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
len(null_cat)
# Out:
# 12

# %%
for i in null_num:
    df[i] = df[i].fillna(df[i].mean())

# %%
null_df = df.isnull().sum().sort_values()
null_df[null_df>0],len(null_df[null_df>0])
# Out:
# (Electrical        1
#  MasVnrType        8
#  BsmtQual         37
#  BsmtCond         37
#  BsmtFinType1     37
#  BsmtFinType2     38
#  BsmtExposure     38
#  GarageQual       81
#  GarageFinish     81
#  GarageType       81
#  GarageCond       81
#  FireplaceQu     690
#  dtype: int64,
#  12)

# %%
null_col = pd.DataFrame(null_df[null_df>0]).index
null_col
# Out:
# Index(['Electrical', 'MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtFinType1',
#        'BsmtFinType2', 'BsmtExposure', 'GarageQual', 'GarageFinish',
#        'GarageType', 'GarageCond', 'FireplaceQu'],
#       dtype='object')

# %%
null_num = []
for i in num_col:
    if i in null_col:
        null_num.append(i)

# %%
null_num
# Out:
# []

# %%
len(null_cat)
# Out:
# 12

# %%
null_cat
# Out:
# ['MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond']

# %%
df['MasVnrType'].mode()[0]
# Out:
# 'None'

# %%
for i in null_cat:
    df[i] = df[i].fillna(df[i].mode()[0])

# %%
null_df = df.isnull().sum().sort_values()
null_df[null_df>0],len(null_df[null_df>0])
# Out:
# (Series([], dtype: int64), 0)

# %%
null_test = test_df.isnull().sum().sort_values()
null_test[null_test>0],len(null_test[null_test>0])
# Out:
# (GarageCars         1
#  GarageArea         1
#  KitchenQual        1
#  Exterior1st        1
#  SaleType           1
#  TotalBsmtSF        1
#  BsmtUnfSF          1
#  Exterior2nd        1
#  BsmtFinSF1         1
#  BsmtFinSF2         1
#  BsmtFullBath       2
#  Functional         2
#  Utilities          2
#  BsmtHalfBath       2
#  MSZoning           4
#  MasVnrArea        15
#  MasVnrType        16
#  BsmtFinType2      42
#  BsmtFinType1      42
#  BsmtExposure      44
#  BsmtQual          44
#  BsmtCond          45
#  GarageType        76
#  GarageFinish      78
#  GarageYrBlt       78
#  GarageQual        78
#  GarageCond        78
#  LotFrontage      227
#  FireplaceQu      730
#  Fence           1169
#  Alley           1352
#  MiscFeature     1408
#  PoolQC          1456
#  dtype: int64,
#  33)

# %%
test_df.drop('PoolQC',axis=1,inplace=True)
test_df.drop(['MiscFeature','Alley','Fence'],axis=1,inplace=True)

# %%
null_test = test_df.isnull().sum().sort_values()
null_test[null_test>0],len(null_test[null_test>0])
# Out:
# (GarageArea        1
#  KitchenQual       1
#  GarageCars        1
#  TotalBsmtSF       1
#  Exterior1st       1
#  Exterior2nd       1
#  BsmtFinSF1        1
#  BsmtFinSF2        1
#  SaleType          1
#  BsmtUnfSF         1
#  BsmtFullBath      2
#  Functional        2
#  Utilities         2
#  BsmtHalfBath      2
#  MSZoning          4
#  MasVnrArea       15
#  MasVnrType       16
#  BsmtFinType2     42
#  BsmtFinType1     42
#  BsmtExposure     44
#  BsmtQual         44
#  BsmtCond         45
#  GarageType       76
#  GarageFinish     78
#  GarageYrBlt      78
#  GarageQual       78
#  GarageCond       78
#  LotFrontage     227
#  FireplaceQu     730
#  dtype: int64,
#  29)

# %%
null_col = pd.DataFrame(null_df[null_df>0]).index
null_col
# Out:
# Index([], dtype='object')

# %%
null_col_t = pd.DataFrame(null_test[null_test>0]).index
null_col_t,len(null_col_t)
# Out:
# (Index(['GarageArea', 'KitchenQual', 'GarageCars', 'TotalBsmtSF', 'Exterior1st',
#         'Exterior2nd', 'BsmtFinSF1', 'BsmtFinSF2', 'SaleType', 'BsmtUnfSF',
#         'BsmtFullBath', 'Functional', 'Utilities', 'BsmtHalfBath', 'MSZoning',
#         'MasVnrArea', 'MasVnrType', 'BsmtFinType2', 'BsmtFinType1',
#         'BsmtExposure', 'BsmtQual', 'BsmtCond', 'GarageType', 'GarageFinish',
#         'GarageYrBlt', 'GarageQual', 'GarageCond', 'LotFrontage',
#         'FireplaceQu'],
#        dtype='object'),
#  29)

# %%
num_col
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
null_num = []
for i in num_col:
    if i in null_col_t:
        null_num.append(i)

# %%
null_num
# Out:
# ['LotFrontage',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea']

# %%
for i in null_num:
    test_df[i] = test_df[i].fillna(test_df[i].mean())

# %%
null_test
# Out:
# Id               0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
#               ...
# GarageYrBlt     78
# GarageQual      78
# GarageCond      78
# LotFrontage    227
# FireplaceQu    730
# Length: 76, dtype: int64

# %%
null_test = test_df.isnull().sum().sort_values()
null_test[null_test>0],len(null_test[null_test>0])
# Out:
# (Exterior1st       1
#  Exterior2nd       1
#  KitchenQual       1
#  SaleType          1
#  Utilities         2
#  Functional        2
#  MSZoning          4
#  MasVnrType       16
#  BsmtFinType1     42
#  BsmtFinType2     42
#  BsmtQual         44
#  BsmtExposure     44
#  BsmtCond         45
#  GarageType       76
#  GarageQual       78
#  GarageFinish     78
#  GarageCond       78
#  FireplaceQu     730
#  dtype: int64,
#  18)

# %%
null_col_t = pd.DataFrame(null_test[null_test>0]).index
null_col_t,len(null_col_t)
# Out:
# (Index(['Exterior1st', 'Exterior2nd', 'KitchenQual', 'SaleType', 'Utilities',
#         'Functional', 'MSZoning', 'MasVnrType', 'BsmtFinType1', 'BsmtFinType2',
#         'BsmtQual', 'BsmtExposure', 'BsmtCond', 'GarageType', 'GarageQual',
#         'GarageFinish', 'GarageCond', 'FireplaceQu'],
#        dtype='object'),
#  18)

# %%
cat_col
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
null_cat = []
for i in cat_col:
    if i in null_col_t:
        null_cat.append(i)

# %%
null_cat
# Out:
# ['MSZoning',
#  'Utilities',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'SaleType']

# %%
len(null_cat)
# Out:
# 18

# %%
for i in null_cat:
    test_df[i] = test_df[i].fillna(test_df[i].mode()[0])

# %%
test_df.isnull().sum().sort_values()
# Out:
# Id               0
# Functional       0
# TotRmsAbvGrd     0
# KitchenQual      0
# KitchenAbvGr     0
#                 ..
# Exterior1st      0
# RoofMatl         0
# RoofStyle        0
# ExterCond        0
# SaleCondition    0
# Length: 76, dtype: int64

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
test_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461          20       RH         80.0    11622   Pave      Reg
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
df
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLI  \
# ...

# %%
y = df['SalePrice']
X = df.drop('SalePrice',axis =  1 )

# %%
X
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLI  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
sc = StandardScaler()

# %%
scaled_X_train = sc.fit_transform(X_train)

# %%
scaled_X_test = sc.transform(X_test)

# %%
rf = RandomForestRegressor()

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
def score(model):
    model.fit(scaled_X_train,y_train)
    y_pred = model.predict(scaled_X_test)
    r2 = r2_score(y_test,y_pred)
    mae = mean_absolute_error(y_test,y_pred)
    mse = np.sqrt(mean_squared_error(y_test,y_pred))
    print( y_test.mean())
    print(f'r2_score: {r2}')
    
    print(f"mae: {mae}")
    
    print(f"mse: {mse}")

# %%
score(rf)
# Out:
# 178839.81164383562
# r2_score: 0.8866486945141363
# mae: 18066.514178082194
# mse: 29486.293240878796

# %%
def score_1(model):
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    r2 = r2_score(y_test,y_pred)
    mae = mean_absolute_error(y_test,y_pred)
    mse = np.sqrt(mean_squared_error(y_test,y_pred))
    print( y_test.mean())
    print(f'r2_score: {r2}')
    
    print(f"mae: {mae}")
    
    print(f"mse: {mse}")

# %%
score_1(rf)
# Out:
# 178839.81164383562
# r2_score: 0.8913156462483349
# mae: 17780.923493150683
# mse: 28872.901601546615

# %%
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)

# %%
pd.Series(y_pred)
# Out:
# 0      141203.75
# 1      325903.60
# 2      114078.08
# 3      153897.00
# 4      318601.85
#          ...
# 287    118054.08
# 288    234155.00
# 289    179322.33
# 290    138406.37
# 291    113178.50
# Length: 292, dtype: float64

# %%
test_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461          20       RH         80.0    11622   Pave      Reg
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
df
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLI  \
# ...

# %%
new_df = df.drop('Id',axis = 1)

# %%
new_df
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %%
y = new_df['SalePrice']
X = new_df.drop('SalePrice',axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
score_1(rf)
# Out:
# 178839.81164383562
# r2_score: 0.896672359094
# mae: 17358.78917808219
# mse: 28152.383770617227

# %%
score_1(rf)
# Out:
# 178839.81164383562
# r2_score: 0.8888873284823038
# mae: 18009.127226027398
# mse: 29193.671168470057

# %%
 param_grid = { 
            "n_estimators"      : [10,20,30,50,70,100,150,200],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8,10,12,15,20],
            "bootstrap": [True, False],
            }

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(rf,param_grid)

# %%
score_1(grid)
# Out:
# 178839.81164383562
# r2_score: 0.8740910922776882
# mae: 18303.06917808219
# mse: 31076.71788688042

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'bootstrap': [True, False],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 4, 8],
#                          'n_estimators': [10, 20, 30]})

# %%
y_pred = grid.predict(X_test)
r2 = r2_score(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
mse = np.sqrt(mean_squared_error(y_test,y_pred))
print( y_test.mean())
print(f'r2_score: {r2}')
    
print(f"mae: {mae}")
    
print(f"mse: {mse}")
# Out:
# 178839.81164383562
# r2_score: 0.8721587479416124
# mae: 18319.68299304197
# mse: 31314.279586525146

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rf.predict(X_test)
r2 = r2_score(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
mse = np.sqrt(mean_squared_error(y_test,y_pred))
print( y_test.mean())
print(f'r2_score: {r2}')
    
print(f"mae: {mae}")
    
print(f"mse: {mse}")
# Out:
# 178839.81164383562
# r2_score: 0.8909915863163511
# mae: 17579.050582191783
# mse: 28915.91416990976

# %%
test_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461          20       RH         80.0    11622   Pave      Reg
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
model = RandomForestRegressor()

# %%
df
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLI  \
# ...

# %%
y = df['SalePrice']
X = df.drop('SalePrice',axis= 1)

# %%
model.fit(X,y)
# Out:
# RandomForestRegressor()

# %%
test_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461          20       RH         80.0    11622   Pave      Reg
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
test_df = pd.get_dummies(test_df,drop_first=True)

# %%
test_df
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     1461          20         80.0    11622            5            6
# 1     1462          20         81.0    14267            6            6
# 2     1463          60         74.0    13830            5            5
# 3     1464          60         78.0     9978            6            6
# 4     1465         120         43.0     5005            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1454  2915         160         21.0     1936            4            7
# 1455  2916         160         21.0     1894            4            5
# 1456  2917          20        160.0    20000            5            7
# 1457  2918          85         62.0    10441            5            5
# 1458  2919          60         74.0     9627            7            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLI  \
# ...

# %%
model.predict(test_df)
# Out:
# e:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names seen at fit time, yet now missing:
# - Condition2_RRAe
# - Condition2_RRAn
# - Condition2_RRNn
# - Electrical_Mix
# - Exterior1st_ImStucc
# - ...
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [114], in <cell line: 1>()
# ----> 1 model.predict(test_df)
#
# File e:\Users\hp\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:971, in ForestRegressor.predict(self, X)
#     969 check_is_fitted(self)
#     970 # Check data
# --> 971 X = self._validate_X_predict(X)
#     973 # Assign chunk of trees to jobs
#     974 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# ...

# %%
df_columns = df.columns

# %%
test_columns  = test_df.columns

# %%
len(df_columns),len(test_columns)
# Out:
# (238, 221)

# %%
not_col = []
for i in df_columns:
    if i not in test_columns:
        not_col.append(i)

# %%
len(not_col)
# Out:
# 17

# %%
not_col
# Out:
# ['SalePrice',
#  'Utilities_NoSeWa',
#  'Condition2_RRAe',
#  'Condition2_RRAn',
#  'Condition2_RRNn',
#  'HouseStyle_2.5Fin',
#  'RoofMatl_CompShg',
#  'RoofMatl_Membran',
#  'RoofMatl_Metal',
#  'RoofMatl_Roll',
#  'Exterior1st_ImStucc',
#  'Exterior1st_Stone',
#  'Exterior2nd_Other',
#  'Heating_GasA',
#  'Heating_OthW',
#  'Electrical_Mix',
#  'GarageQual_Fa']

# %%
test_df['Sal']

# %%
correlation = df.corr()['SalePrice']

# %%
correlation[['SalePrice',
 'Utilities_NoSeWa',
 'Condition2_RRAe',
 'Condition2_RRAn',
 'Condition2_RRNn',
 'HouseStyle_2.5Fin',
 'RoofMatl_CompShg',
 'RoofMatl_Membran',
 'RoofMatl_Metal',
 'RoofMatl_Roll',
 'Exterior1st_ImStucc',
 'Exterior1st_Stone',
 'Exterior2nd_Other',
 'Heating_GasA',
 'Heating_OthW',
 'Electrical_Mix',
 'GarageQual_Fa']]
# Out:
# SalePrice              1.000000
# Utilities_NoSeWa      -0.014314
# Condition2_RRAe        0.002993
# Condition2_RRAn       -0.014510
# Condition2_RRNn       -0.039255
# HouseStyle_2.5Fin      0.036526
# RoofMatl_CompShg      -0.104505
# RoofMatl_Membran       0.019970
# RoofMatl_Metal        -0.000304
# RoofMatl_Roll         -0.014479
# Exterior1st_ImStucc    0.026729
# Exterior1st_Stone      0.036181
# Exterior2nd_Other      0.045519
# Heating_GasA           0.092529
# Heating_OthW          -0.025730
# Electrical_Mix        -0.037555
# GarageQual_Fa         -0.133142
# Name: SalePrice, dtype: float64

# %%
naya_df = df.drop(['Utilities_NoSeWa',
 'Condition2_RRAe',
 'Condition2_RRAn',
 'Condition2_RRNn',
 'HouseStyle_2.5Fin',
 'RoofMatl_CompShg',
 'RoofMatl_Membran',
 'RoofMatl_Metal',
 'RoofMatl_Roll',
 'Exterior1st_ImStucc',
 'Exterior1st_Stone',
 'Exterior2nd_Other',
 'Heating_GasA',
 'Heating_OthW',
 'Electrical_Mix',
 'GarageQual_Fa'],axis = 1)

# %%
naya_df
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLI  \
# ...

# %%
X = naya_df.drop(['SalePrice'],axis = 1)
y = naya_df['SalePrice']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
rf = RandomForestRegressor()

# %%
score_1(rf)
# Out:
# 178839.81164383562
# r2_score: 0.8883542351632681
# mae: 18043.631506849317
# mse: 29263.619665869013

# %%
score_1(rf)
# Out:
# 178839.81164383562
# r2_score: 0.8861222557415316
# mae: 18082.55976027397
# mse: 29554.685689431444

# %%
final_model = RandomForestRegressor()

# %%
final_model.fit(X,y)
# Out:
# RandomForestRegressor()

# %%
final_prediction = final_model.predict(test_df)

# %%
pd.DataFrame(final_prediction)
# Out:
#               0
# 0     128779.50
# 1     151471.50
# 2     182481.10
# 3     179037.57
# 4     200329.00
# ...         ...
# 1454   84645.00
# 1455   86780.93
# 1456  151929.48
# 1457  114305.00
# 1458  224215.49
#
# [1459 rows x 1 columns]

# %%
submission = test_df[['Id']]

# %%
submission['SalePrice'] = final_prediction
# Out:
#         Id
# 0     1461
# 1     1462
# 2     1463
# 3     1464
# 4     1465
# ...    ...
# 1454  2915
# 1455  2916
# 1456  2917
# 1457  2918
# 1458  2919
#
# [1459 rows x 1 columns]

# %%
submission['SalePrice'] = final_prediction
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21648\3477429608.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submission['SalePrice'] = final_prediction

# %%
submission
# Out:
#         Id  SalePrice
# 0     1461  128779.50
# 1     1462  151471.50
# 2     1463  182481.10
# 3     1464  179037.57
# 4     1465  200329.00
# ...    ...        ...
# 1454  2915   84645.00
# 1455  2916   86780.93
# 1456  2917  151929.48
# 1457  2918  114305.00
# 1458  2919  224215.49
#
# [1459 rows x 2 columns]

# %%
submission.to_csv("submission.csv",index=None)

# %%
pd.read_csv('submission.csv')
# Out:
#         Id  SalePrice
# 0     1461  128779.50
# 1     1462  151471.50
# 2     1463  182481.10
# 3     1464  179037.57
# 4     1465  200329.00
# ...    ...        ...
# 1454  2915   84645.00
# 1455  2916   86780.93
# 1456  2917  151929.48
# 1457  2918  114305.00
# 1458  2919  224215.49
#
# [1459 rows x 2 columns]
